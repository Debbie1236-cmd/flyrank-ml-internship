# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Debbie1236-cmd/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My LLM evaluation lane is best framed as a ranking task because it involves comparing multiple AI responses and ranking them from the best response to the worst response. This ranking helps identify higher-quality responses that can be used to improve future AI models.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# The target is the ranking of AI responses based on quality. The model predicts which response is better. The labels come from human evaluators who compare responses using defined annotation guidelines and rank them from best to worst.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is the ranking of AI responses based on quality. The model predicts which response is better. The labels come from human evaluators who compare responses using annotation guidelines and rank them from best to worst.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# A success metric measures how well the model performs. Instead of simply saying the model is good, it uses a measurable number to show how accurately the model's predictions match the rankings given by human evaluators. A higher accuracy means the model is performing well.

# %%
# This cell is for CODE (numbers, a query, a check).

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row represents one content page. Each row contains information about a single webpage, including its search performance, engagement metrics, content characteristics, and other features that can be used for machine learning.

# %%
df.head(1)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Machine learning is better than a fixed rule because it can learn patterns from many features working together. The dataset contains multiple factors, such as search volume, competition, engagement rate, and traffic, that influence the outcome. A simple if-else rule cannot effectively handle these complex relationships, but a machine learning model can learn them from the data.

# %%
# This cell is for CODE (numbers, a query, a check).

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
